# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import glob
import cv2
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
daftar_huruf = glob.glob('/content/drive/MyDrive/AKSARA/Batak/*')
daftar_huruf_nama = [_+"/"+_.split('/')[-1]+".png" for _ in daftar_huruf]
daftar_huruf_kosong = []

for nama in daftar_huruf_nama:
  _ = cv2.imread(nama)
  print(nama.split('/')[-1], np.sum(255-_))

  if np.sum(255-_)==0:
    daftar_huruf_kosong.append(nama.split('/')[-1].split('.')[0])
# Out:
# BATAK_LETTER_BA.png 11937567
# BATAK_CONSONANT_SIGN_NG.png 580554
# BATAK_CONSONANT_SIGN_H.png 1046424
# BATAK_LETTER_DA.png 6236637
# BATAK_LETTER_A.png 9446751
# BATAK_LETTER_JA.png 8134785
# BATAK_LETTER_I.png 7769349
# BATAK_LETTER_HA.png 9532443
# BATAK_LETTER_GA.png 5711034
# BATAK_LETTER_CA.png 9188376
# BATAK_LETTER_NGA.png 6538770
# BATAK_LETTER_MA.png 10749075
# BATAK_LETTER_MANDAILING_SA.png 7319085
# BATAK_LETTER_MBA.png 11126328
# BATAK_LETTER_NDA.png 6158802
# BATAK_LETTER_KARO_BA.png 10215021
# BATAK_LETTER_MANDAILING_NA.png 12091089
# BATAK_LETTER_MANDAILING_HA.png 9046413
# BATAK_LETTER_NA.png 11223783
# BATAK_LETTER_LA.png 5781009
# BATAK_LETTER_SIMALUNGUN_A.png 8517978
# BATAK_LETTER_SIMALUNGUN_HA.png 7652520
# BATAK_LETTER_SIMALUNGUN_GA.png 6350919
# BATAK_LETTER_PA.png 3762297
# BATAK_LETTER_NORTHERN_TA.png 9983049
# BATAK_LETTER_SA.png 7628505
# BATAK_LETTER_NYA.png 7120968
# BATAK_LETTER_PAKPAK_WA.png 7379226
# BATAK_LETTER_SIMALUNGUN_LA.png 6345396
# BATAK_LETTER_RA.png 9936450
# BATAK_LETTER_U.png 7781184
# BATAK_LETTER_SOUTHERN_TA.png 9490473
# BATAK_LETTER_SIMALUNGUN_WA.png 7649697
# BATAK_LETTER_SIMALUNGUN_MA.png 8569542
# BATAK_LETTER_SIMALUNGUN_SA.png 6347529
# BATAK_LETTER_SIMALUNGUN_PA.png 4800567
# BATAK_LETTER_YA.png 8606481
# BATAK_LETTER_SIMALUNGUN_YA.png 8262564
# BATAK_LETTER_SIMALUNGUN_RA.png 7796838
# BATAK_LETTER_WA.png 9256020
# BATAK_VOWEL_SIGN_I.png 5259642
# BATAK_SYMBOL_BINDU_PANGOLAT.png 6401247
# BATAK_VOWEL_SIGN_E.png 2617755
# BATAK_PANGOLAT.png 2806419
# BATAK_SYMBOL_BINDU_PINARBORAS.png 14060970
# BATAK_PANONGONAN.png 1790463
# BATAK_SYMBOL_BINDU_JUDUL.png 14388786
# BATAK_SYMBOL_BINDU_NA_METEK.png 19644777
# BATAK_VOWEL_SIGN_U.png 2616585
# BATAK_VOWEL_SIGN_KARO_I.png 2098503
# BATAK_VOWEL_SIGN_O.png 4971963

# %%
def autoCrop(this_image):
    image_data_bw = this_image.max(axis=2)
    non_empty_columns = np.where(image_data_bw.min(axis=0)<0.2)[0]
    non_empty_rows = np.where(image_data_bw.min(axis=1)<0.2)[0]
    cropBox = (min(non_empty_rows), max(non_empty_rows), min(non_empty_columns), max(non_empty_columns))

    image_data_new = this_image[cropBox[0]:cropBox[1]+1, cropBox[2]:cropBox[3]+1 , :]
    
    return image_data_new

# %%
'''daftar_huruf = glob.glob('/content/drive/MyDrive/AKSARA/Batak/*')
daftar_huruf_nama = [_+"/"+_.split('/')[-1]+".png" for _ in daftar_huruf]
daftar_huruf_kosong = []

for nama in daftar_huruf_nama:
  _ = cv2.imread(nama)
  print(nama.split('/')[-1], np.sum(255-_))
  _ = autoCrop(_)
  cv2.imwrite(nama, _)'''
# Out:
# BATAK_LETTER_BA.png 11937567
# BATAK_CONSONANT_SIGN_NG.png 580554
# BATAK_CONSONANT_SIGN_H.png 1046424
# BATAK_LETTER_DA.png 6236637
# BATAK_LETTER_A.png 9446751
# BATAK_LETTER_JA.png 8134785
# BATAK_LETTER_I.png 7769349
# BATAK_LETTER_HA.png 9532443
# BATAK_LETTER_GA.png 5711034
# BATAK_LETTER_CA.png 9188376
# BATAK_LETTER_NGA.png 6538770
# BATAK_LETTER_MA.png 10749075
# BATAK_LETTER_MANDAILING_SA.png 7319085
# BATAK_LETTER_MBA.png 11126328
# BATAK_LETTER_NDA.png 6158802
# BATAK_LETTER_KARO_BA.png 10215021
# BATAK_LETTER_MANDAILING_NA.png 12091089
# BATAK_LETTER_MANDAILING_HA.png 9046413
# BATAK_LETTER_NA.png 11223783
# BATAK_LETTER_LA.png 5781009
# BATAK_LETTER_SIMALUNGUN_A.png 8517978
# BATAK_LETTER_SIMALUNGUN_HA.png 7652520
# BATAK_LETTER_SIMALUNGUN_GA.png 6350919
# BATAK_LETTER_PA.png 3762297
# BATAK_LETTER_NORTHERN_TA.png 9983049
# BATAK_LETTER_SA.png 7628505
# BATAK_LETTER_NYA.png 7120968
# BATAK_LETTER_PAKPAK_WA.png 7379226
# BATAK_LETTER_SIMALUNGUN_LA.png 6345396
# BATAK_LETTER_RA.png 9936450
# BATAK_LETTER_U.png 7781184
# BATAK_LETTER_SOUTHERN_TA.png 9490473
# BATAK_LETTER_SIMALUNGUN_WA.png 7649697
# BATAK_LETTER_SIMALUNGUN_MA.png 8569542
# BATAK_LETTER_SIMALUNGUN_SA.png 6347529
# BATAK_LETTER_SIMALUNGUN_PA.png 4800567
# BATAK_LETTER_YA.png 8606481
# BATAK_LETTER_SIMALUNGUN_YA.png 8262564
# BATAK_LETTER_SIMALUNGUN_RA.png 7796838
# BATAK_LETTER_WA.png 9256020
# BATAK_VOWEL_SIGN_I.png 5259642
# BATAK_SYMBOL_BINDU_PANGOLAT.png 6401247
# BATAK_VOWEL_SIGN_E.png 2617755
# BATAK_PANGOLAT.png 2806419
# BATAK_SYMBOL_BINDU_PINARBORAS.png 14060970
# BATAK_PANONGONAN.png 1790463
# BATAK_SYMBOL_BINDU_JUDUL.png 14388786
# BATAK_SYMBOL_BINDU_NA_METEK.png 19644777
# BATAK_VOWEL_SIGN_U.png 2616585
# BATAK_VOWEL_SIGN_KARO_I.png 2098503
# BATAK_VOWEL_SIGN_O.png 4971963

# %%
'''import shutil

for i in daftar_huruf_kosong:
  shutil.rmtree('/content/drive/MyDrive/AKSARA/Batak/' + i)'''

# %%
'''!pip install Augmentor'''
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.10-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.8/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.8/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.8/dist-packages (from Augmentor) (4.64.1)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.10

# %%
'''import Augmentor

def perbanyak(ini, sebanyak_ini):
  p = Augmentor.Pipeline(source_directory=ini, output_directory='.')
  p.random_distortion(probability=1, grid_width=2, grid_height=2, magnitude=1)
  p.rotate(probability=0.7, max_left_rotation=6, max_right_rotation=6)
  p.zoom_random(probability=0.7, percentage_area=0.9)
  p.resize(probability=1, width=64, height=64)
  p.sample(sebanyak_ini)'''

# %%
'''batak = glob.glob("/content/drive/MyDrive/AKSARA/Batak/*")

for huruf in batak:
  perbanyak(huruf, 20)'''
# Out:
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_BA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37394EF970>: 100%|██████████| 20/20 [00:00<00:00, 56.56 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_CONSONANT_SIGN_NG/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F373958EBE0>: 100%|██████████| 20/20 [00:00<00:00, 96.27 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_CONSONANT_SIGN_H/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37394FAD30>: 100%|██████████| 20/20 [00:00<00:00, 75.63 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_DA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3739501820>: 100%|██████████| 20/20 [00:00<00:00, 58.72 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_A/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F373AA853A0>: 100%|██████████| 20/20 [00:00<00:00, 49.35 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_JA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736292730>: 100%|██████████| 20/20 [00:00<00:00, 53.11 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_I/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37394E1DC0>: 100%|██████████| 20/20 [00:00<00:00, 52.46 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_HA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736292EB0>: 100%|██████████| 20/20 [00:00<00:00, 53.78 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_GA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736293BB0>: 100%|██████████| 20/20 [00:00<00:00, 64.54 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_CA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F373959CA30>: 100%|██████████| 20/20 [00:00<00:00, 57.23 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_NGA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736292610>: 100%|██████████| 20/20 [00:00<00:00, 63.04 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_MA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736298220>: 100%|██████████| 20/20 [00:00<00:00, 53.92 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_MANDAILING_SA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3739E1E0D0>: 100%|██████████| 20/20 [00:00<00:00, 54.08 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_MBA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37362A24F0>: 100%|██████████| 20/20 [00:00<00:00, 59.75 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_NDA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37362A8070>: 100%|██████████| 20/20 [00:00<00:00, 59.48 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_KARO_BA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37362AF880>: 100%|██████████| 20/20 [00:00<00:00, 56.74 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_MANDAILING_NA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37362A8E80>: 100%|██████████| 20/20 [00:00<00:00, 50.77 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_MANDAILING_HA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37362A2070>: 100%|██████████| 20/20 [00:00<00:00, 49.75 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_NA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37362B89A0>: 100%|██████████| 20/20 [00:00<00:00, 55.22 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_LA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F373AA853A0>: 100%|██████████| 20/20 [00:00<00:00, 60.06 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_SIMALUNGUN_A/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37362BBA90>: 100%|██████████| 20/20 [00:00<00:00, 53.97 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_SIMALUNGUN_HA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37362BB910>: 100%|██████████| 20/20 [00:00<00:00, 60.49 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_SIMALUNGUN_GA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736287C70>: 100%|██████████| 20/20 [00:00<00:00, 51.06 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_PA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37362AD340>: 100%|██████████| 20/20 [00:00<00:00, 80.54 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_NORTHERN_TA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736243070>: 100%|██████████| 20/20 [00:00<00:00, 56.56 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_SA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F373627FB80>: 100%|██████████| 20/20 [00:00<00:00, 51.65 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_NYA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736252AF0>: 100%|██████████| 20/20 [00:00<00:00, 52.81 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_PAKPAK_WA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37362438B0>: 100%|██████████| 20/20 [00:00<00:00, 41.48 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_SIMALUNGUN_LA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736245FA0>: 100%|██████████| 20/20 [00:00<00:00, 53.64 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_RA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736252850>: 100%|██████████| 20/20 [00:00<00:00, 52.62 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_U/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736245FA0>: 100%|██████████| 20/20 [00:00<00:00, 52.05 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_SOUTHERN_TA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736256C70>: 100%|██████████| 20/20 [00:00<00:00, 61.37 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_SIMALUNGUN_WA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736256B20>: 100%|██████████| 20/20 [00:00<00:00, 54.89 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_SIMALUNGUN_MA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3739532820>: 100%|██████████| 20/20 [00:00<00:00, 53.37 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_SIMALUNGUN_SA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F373625D9D0>: 100%|██████████| 20/20 [00:00<00:00, 55.56 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_SIMALUNGUN_PA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736243C10>: 100%|██████████| 20/20 [00:00<00:00, 59.24 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_YA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37362B8DF0>: 100%|██████████| 20/20 [00:00<00:00, 53.57 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_SIMALUNGUN_YA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F373626C430>: 100%|██████████| 20/20 [00:00<00:00, 53.96 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_SIMALUNGUN_RA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F373624B250>: 100%|██████████| 20/20 [00:00<00:00, 58.87 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_LETTER_WA/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F373625CA90>: 100%|██████████| 20/20 [00:00<00:00, 56.77 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_VOWEL_SIGN_I/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736274CA0>: 100%|██████████| 20/20 [00:00<00:00, 59.43 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_SYMBOL_BINDU_PANGOLAT/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736258A00>: 100%|██████████| 20/20 [00:00<00:00, 55.41 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_VOWEL_SIGN_E/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736261E80>: 100%|██████████| 20/20 [00:00<00:00, 63.32 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_PANGOLAT/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37362061C0>: 100%|██████████| 20/20 [00:00<00:00, 62.27 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_SYMBOL_BINDU_PINARBORAS/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736203B20>: 100%|██████████| 20/20 [00:00<00:00, 33.11 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_PANONGONAN/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736206E80>: 100%|██████████| 20/20 [00:00<00:00, 60.75 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_SYMBOL_BINDU_JUDUL/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F373620DAF0>: 100%|██████████| 20/20 [00:00<00:00, 42.69 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_SYMBOL_BINDU_NA_METEK/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F373626EF10>: 100%|██████████| 20/20 [00:00<00:00, 43.51 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_VOWEL_SIGN_U/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F3736266EE0>: 100%|██████████| 20/20 [00:00<00:00, 64.14 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_VOWEL_SIGN_KARO_I/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37362123D0>: 100%|██████████| 20/20 [00:00<00:00, 65.15 Samples/s]
# Initialised with 1 image(s) found.
# Output directory set to /content/drive/MyDrive/AKSARA/Batak/BATAK_VOWEL_SIGN_O/..
# Processing <PIL.Image.Image image mode=RGB size=64x64 at 0x7F37362BBA00>: 100%|██████████| 20/20 [00:00<00:00, 61.49 Samples/s]

# %%
x = []
y = []

daftar_huruf = glob.glob('/content/drive/MyDrive/AKSARA/Batak/*')

for c, jenis_huruf in enumerate(daftar_huruf):
  list_huruf = glob.glob(jenis_huruf + '/*')
  for huruf in list_huruf:
    try:
      aksara = cv2.imread(huruf)
      aksara = aksara/255
      #aksara = autoCrop(aksara)
      if aksara.shape[0] == 0 or aksara.shape[1] == 1:
        continue
      else:
        aksara = cv2.resize(aksara, (64, 64))
        x.append(aksara)
        y.append(c)
    except:
      continue

# %%
len(x)
# Out:
# 1071

# %%
len(set(y))
# Out:
# 51

# %%
1071/51
# Out:
# 21.0

# %%
z = list(zip(x,y))
random.shuffle(z)
x, y = zip(*z)
x = np.asarray(x).astype(float)
y = np.asarray(y)

# %%
plt.imshow(x[10])

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation
from keras.preprocessing.image import ImageDataGenerator
from keras.metrics import accuracy, categorical_accuracy

model = Sequential()

model.add(Conv2D(2, (3, 3), input_shape = x.shape[1:], activation = 'relu'))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(4, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(16, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(2, 2))

model.add(Flatten())
model.add(Dense(units = 51, activation = 'softmax'))

model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(x, y, batch_size = 2, epochs = 20, validation_split = 0.2)
# Out:
# Epoch 1/20
# 428/428 [==============================] - 5s 9ms/step - loss: 1.7253 - accuracy: 0.5771 - val_loss: 0.5099 - val_accuracy: 0.8512
# Epoch 2/20
# 428/428 [==============================] - 4s 9ms/step - loss: 0.3045 - accuracy: 0.9042 - val_loss: 0.3561 - val_accuracy: 0.9070
# Epoch 3/20
# 428/428 [==============================] - 4s 9ms/step - loss: 0.2223 - accuracy: 0.9159 - val_loss: 0.4297 - val_accuracy: 0.9070
# Epoch 4/20
# 428/428 [==============================] - 4s 9ms/step - loss: 0.1559 - accuracy: 0.9311 - val_loss: 0.4796 - val_accuracy: 0.8791
# Epoch 5/20
# 428/428 [==============================] - 4s 8ms/step - loss: 0.1483 - accuracy: 0.9463 - val_loss: 0.2444 - val_accuracy: 0.9209
# Epoch 6/20
# 428/428 [==============================] - 3s 8ms/step - loss: 0.1404 - accuracy: 0.9498 - val_loss: 0.2016 - val_accuracy: 0.9209
# Epoch 7/20
# 428/428 [==============================] - 4s 8ms/step - loss: 0.1012 - accuracy: 0.9638 - val_loss: 0.2479 - val_accuracy: 0.9070
# Epoch 8/20
# 428/428 [==============================] - 4s 9ms/step - loss: 0.1240 - accuracy: 0.9661 - val_loss: 0.2220 - val_accuracy: 0.9163
# Epoch 9/20
# 428/428 [==============================] - 4s 9ms/step - loss: 0.0981 - accuracy: 0.9614 - val_loss: 0.1804 - val_accuracy: 0.9256
# Epoch 10/20
# 428/428 [==============================] - 4s 8ms/step - loss: 0.0827 - accuracy: 0.9696 - val_loss: 0.2489 - val_accuracy: 0.9163
# Epoch 11/20
# 428/428 [==============================] - 3s 8ms/step - loss: 0.0693 - accuracy: 0.9790 - val_loss: 0.1650 - val_accuracy: 0.9302
# Epoch 12/20
# 428/428 [==============================] - 4s 9ms/step - loss: 0.0683 - accuracy: 0.9766 - val_loss: 0.2049 - val_accuracy: 0.9070
# Epoch 13/20
# 428/428 [==============================] - 3s 8ms/step - loss: 0.0811 - accuracy: 0.9708 - val_loss: 0.1880 - val_accuracy: 0.9163
# Epoch 14/20
# 428/428 [==============================] - 3s 8ms/step - loss: 0.0568 - accuracy: 0.9778 - val_loss: 0.2095 - val_accuracy: 0.9302
# Epoch 15/20
# 428/428 [==============================] - 3s 8ms/step - loss: 0.0518 - accuracy: 0.9766 - val_loss: 0.2252 - val_accuracy: 0.9209
# Epoch 16/20
# 428/428 [==============================] - 4s 9ms/step - loss: 0.0925 - accuracy: 0.9638 - val_loss: 0.1892 - val_accuracy: 0.9395
# Epoch 17/20
# 428/428 [==============================] - 4s 9ms/step - loss: 0.0635 - accuracy: 0.9766 - val_loss: 0.2218 - val_accuracy: 0.9395
# Epoch 18/20
# 428/428 [==============================] - 5s 11ms/step - loss: 0.0484 - accuracy: 0.9825 - val_loss: 0.2022 - val_accuracy: 0.9302
# Epoch 19/20
# 428/428 [==============================] - 4s 9ms/step - loss: 0.0586 - accuracy: 0.9743 - val_loss: 0.2339 - val_accuracy: 0.9349
# Epoch 20/20
# 428/428 [==============================] - 3s 8ms/step - loss: 0.0510 - accuracy: 0.9766 - val_loss: 0.1915 - val_accuracy: 0.9349

# %%
print("->", 0)
history = model.fit(x, y, batch_size=2, epochs=2, validation_split=0.1)

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

for i in range(1, 20):
  z = list(zip(x,y))
  random.shuffle(z)
  del x, y
  x, y = zip(*z)
  x = np.asarray(x).astype(float)
  y = np.asarray(y)
  del z

  print("->", i)
  history = model.fit(x, y, batch_size=2, epochs=2, validation_split=0.1)
  
  accuracy = np.concatenate((accuracy, history.history['accuracy']), axis=0)
  val_accuracy = np.concatenate((val_accuracy, history.history['val_accuracy']), axis=0)
  loss = np.concatenate((loss, history.history['loss']), axis=0)
  val_loss = np.concatenate((val_loss, history.history['val_loss']), axis=0)
# Out:
# -> 0
# Epoch 1/2
# 482/482 [==============================] - 9s 14ms/step - loss: 1.8288 - accuracy: 0.5483 - val_loss: 0.6469 - val_accuracy: 0.7778
# Epoch 2/2
# 482/482 [==============================] - 6s 12ms/step - loss: 0.4636 - accuracy: 0.8494 - val_loss: 0.5064 - val_accuracy: 0.8241
# -> 1
# Epoch 1/2
# 482/482 [==============================] - 3s 6ms/step - loss: 0.3451 - accuracy: 0.8754 - val_loss: 0.1946 - val_accuracy: 0.9167
# Epoch 2/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.2783 - accuracy: 0.8941 - val_loss: 0.2415 - val_accuracy: 0.9167
# -> 2
# Epoch 1/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.2377 - accuracy: 0.9045 - val_loss: 0.2763 - val_accuracy: 0.9074
# Epoch 2/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.1995 - accuracy: 0.9242 - val_loss: 0.1653 - val_accuracy: 0.9537
# -> 3
# Epoch 1/2
# 482/482 [==============================] - 3s 6ms/step - loss: 0.1756 - accuracy: 0.9273 - val_loss: 0.1523 - val_accuracy: 0.9352
# Epoch 2/2
# 482/482 [==============================] - 3s 6ms/step - loss: 0.1576 - accuracy: 0.9377 - val_loss: 0.2044 - val_accuracy: 0.9259
# -> 4
# Epoch 1/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.1517 - accuracy: 0.9325 - val_loss: 0.2649 - val_accuracy: 0.9167
# Epoch 2/2
# 482/482 [==============================] - 3s 6ms/step - loss: 0.1425 - accuracy: 0.9450 - val_loss: 0.1173 - val_accuracy: 0.9167
# -> 5
# Epoch 1/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.1161 - accuracy: 0.9512 - val_loss: 0.1304 - val_accuracy: 0.9630
# Epoch 2/2
# 482/482 [==============================] - 3s 6ms/step - loss: 0.1147 - accuracy: 0.9533 - val_loss: 0.1160 - val_accuracy: 0.9537
# -> 6
# Epoch 1/2
# 482/482 [==============================] - 5s 10ms/step - loss: 0.1327 - accuracy: 0.9491 - val_loss: 0.1216 - val_accuracy: 0.9444
# Epoch 2/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.1075 - accuracy: 0.9512 - val_loss: 0.1200 - val_accuracy: 0.9444
# -> 7
# Epoch 1/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0991 - accuracy: 0.9522 - val_loss: 0.1914 - val_accuracy: 0.9259
# Epoch 2/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0885 - accuracy: 0.9626 - val_loss: 0.1018 - val_accuracy: 0.9537
# -> 8
# Epoch 1/2
# 482/482 [==============================] - 4s 9ms/step - loss: 0.0994 - accuracy: 0.9574 - val_loss: 0.0730 - val_accuracy: 0.9630
# Epoch 2/2
# 482/482 [==============================] - 3s 6ms/step - loss: 0.1085 - accuracy: 0.9585 - val_loss: 0.0605 - val_accuracy: 0.9815
# -> 9
# Epoch 1/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0804 - accuracy: 0.9647 - val_loss: 0.1126 - val_accuracy: 0.9537
# Epoch 2/2
# 482/482 [==============================] - 3s 6ms/step - loss: 0.0855 - accuracy: 0.9637 - val_loss: 0.0912 - val_accuracy: 0.9722
# -> 10
# Epoch 1/2
# 482/482 [==============================] - 4s 9ms/step - loss: 0.0795 - accuracy: 0.9678 - val_loss: 0.0766 - val_accuracy: 0.9537
# Epoch 2/2
# 482/482 [==============================] - 3s 6ms/step - loss: 0.0888 - accuracy: 0.9605 - val_loss: 0.0760 - val_accuracy: 0.9815
# -> 11
# Epoch 1/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0672 - accuracy: 0.9678 - val_loss: 0.0899 - val_accuracy: 0.9630
# Epoch 2/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0778 - accuracy: 0.9657 - val_loss: 0.0914 - val_accuracy: 0.9630
# -> 12
# Epoch 1/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0592 - accuracy: 0.9792 - val_loss: 0.1090 - val_accuracy: 0.9444
# Epoch 2/2
# 482/482 [==============================] - 3s 6ms/step - loss: 0.0677 - accuracy: 0.9688 - val_loss: 0.0974 - val_accuracy: 0.9352
# -> 13
# Epoch 1/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0685 - accuracy: 0.9647 - val_loss: 0.1174 - val_accuracy: 0.9537
# Epoch 2/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0606 - accuracy: 0.9709 - val_loss: 0.0847 - val_accuracy: 0.9630
# -> 14
# Epoch 1/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0675 - accuracy: 0.9668 - val_loss: 0.0343 - val_accuracy: 0.9907
# Epoch 2/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0672 - accuracy: 0.9709 - val_loss: 0.0405 - val_accuracy: 0.9907
# -> 15
# Epoch 1/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0808 - accuracy: 0.9678 - val_loss: 0.0589 - val_accuracy: 0.9722
# Epoch 2/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0583 - accuracy: 0.9699 - val_loss: 0.0674 - val_accuracy: 0.9630
# -> 16
# Epoch 1/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0533 - accuracy: 0.9772 - val_loss: 0.0896 - val_accuracy: 0.9537
# Epoch 2/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0614 - accuracy: 0.9740 - val_loss: 0.0750 - val_accuracy: 0.9537
# -> 17
# Epoch 1/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0641 - accuracy: 0.9720 - val_loss: 0.0810 - val_accuracy: 0.9630
# Epoch 2/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0502 - accuracy: 0.9813 - val_loss: 0.0827 - val_accuracy: 0.9630
# -> 18
# Epoch 1/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0606 - accuracy: 0.9730 - val_loss: 0.0847 - val_accuracy: 0.9630
# Epoch 2/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0586 - accuracy: 0.9740 - val_loss: 0.0672 - val_accuracy: 0.9537
# -> 19
# Epoch 1/2
# 482/482 [==============================] - 3s 7ms/step - loss: 0.0476 - accuracy: 0.9844 - val_loss: 0.1349 - val_accuracy: 0.9352
# Epoch 2/2
# 482/482 [==============================] - 3s 6ms/step - loss: 0.0519 - accuracy: 0.9803 - val_loss: 0.0463 - val_accuracy: 0.9907

# %%
plt.plot(accuracy, 'orange', val_accuracy, 'blue')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(loss, 'orange', val_loss, 'red')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model.save_weights("Model_Batak_FIX.h5")

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

y_pred = model.predict(x[-1000:])
y_pred = np.argmax(y_pred, axis=1)

print(accuracy_score(y_pred, y[-1000:]))
cm = confusion_matrix(y_pred, y[-1000:])
print(cm)

print(classification_report(y_pred, y[-1000:]))
# Out:
# 32/32 [==============================] - 1s 25ms/step
# 0.981
# [[20  0  0 ...  0  0  0]
#  [ 0 18  0 ...  0  0  0]
#  [ 0  0 17 ...  0  0  0]
#  ...
#  [ 0  0  0 ... 12  0  0]
#  [ 0  0  0 ...  0 19  0]
#  [ 0  0  0 ...  0  0 19]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        18
#            2       0.94      1.00      0.97        17
#            3       1.00      1.00      1.00        19
#            4       1.00      1.00      1.00        20
#            5       1.00      1.00      1.00        20
#            6       1.00      1.00      1.00        21
#            7       1.00      1.00      1.00        21
#            8       1.00      1.00      1.00        18
#            9       1.00      1.00      1.00        20
#           10       1.00      1.00      1.00        20
#           11       1.00      1.00      1.00        18
#           12       1.00      1.00      1.00        20
#           13       1.00      1.00      1.00        20
#           14       1.00      1.00      1.00        20
#           15       1.00      1.00      1.00        20
#           16       1.00      1.00      1.00        21
#           17       1.00      1.00      1.00        21
#           18       1.00      1.00      1.00        20
#           19       1.00      1.00      1.00        21
#           20       1.00      1.00      1.00        19
#           21       1.00      1.00      1.00        20
#           22       0.95      1.00      0.97        19
#           23       0.94      0.94      0.94        18
#           24       0.95      1.00      0.98        20
#           25       1.00      1.00      1.00        19
#           26       1.00      1.00      1.00        21
#           27       1.00      1.00      1.00        20
#           28       1.00      1.00      1.00        20
#           29       1.00      1.00      1.00        18
#           30       1.00      1.00      1.00        20
#           31       1.00      1.00      1.00        18
#           32       1.00      0.95      0.97        20
#           33       1.00      1.00      1.00        19
#           34       1.00      1.00      1.00        18
#           35       1.00      1.00      1.00        20
#           36       1.00      0.82      0.90        22
#           37       0.84      1.00      0.91        16
#           38       1.00      1.00      1.00        21
#           39       1.00      1.00      1.00        20
#           40       1.00      1.00      1.00        19
#           41       1.00      1.00      1.00        19
#           42       0.85      0.68      0.76        25
#           43       1.00      1.00      1.00        19
#           44       1.00      1.00      1.00        21
#           45       0.95      0.91      0.93        22
#           46       1.00      1.00      1.00        20
#           47       1.00      1.00      1.00        19
#           48       0.60      0.80      0.69        15
#           49       1.00      1.00      1.00        19
#           50       1.00      1.00      1.00        19
#
#     accuracy                           0.98      1000
#    macro avg       0.98      0.98      0.98      1000
# weighted avg       0.98      0.98      0.98      1000

# %%
daftar_huruf[42]
# Out:
# '/content/drive/MyDrive/AKSARA/Batak/BATAK_VOWEL_SIGN_E'

# %%
import seaborn as sns

sns.heatmap(cm)
